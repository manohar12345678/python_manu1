# %%
# 1. Import Python Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Done")
# Out:
# Done

# %%
# 2. Importing data from "youtube_dataset.csv"
df = "youtube_dataset.csv"
youtubedataset_original = pd.read_csv(df)

# %%
# Def Function
# Sort subscribers in descending order
# Create top 1000 subscribers and save the new dataset.

# %%
def youtube(df, country):
    df1 = df.sort_values(by=['subscribers'],ascending = False)
    df2 = df1.iloc[:1000,:]
    df2.to_csv('newyoutubedata_top1k.csv')
    print(df2.groupby(country)[country].count().reset_index(name='Channel Count').sort_values(['Channel Count'], ascending=False))
       
# 4. Calling the function
youtube(youtubedata_unsorted,'country')
# Out:
#    country  Channel Count
# 47      US            397
# 6       BR            110
# 20      IN             83
# 16      GB             56
# 28      MX             38
# 14      ES             34
# 8       CA             23
# 40      RU             18
# 26      KR             17
# 3       AU             15
# 44      TH             13
# 11      CO             13
# 18      ID             12
# 15      FR             11
# 1       AR              8
# 50      VN              7
# 12      DE              6
# 41      SA              6
# 45      TR              6
# 36      PR              6
# 0       AE              5
# 34      PH              4
# 49      VE              3
# 46      UA              3
# 9       CL              3
# 33      PE              3
# 21      IQ              2
# 31      NZ              2
# 42      SE              2
# 22      IT              2
# 25      JP              2
# 30      NO              2
# 29      NL              2
# 24      JO              2
# ...

# %%
# 5. Print newyoutubedata_top1k.csv
df3= pd.read_csv('newyoutubedata_top1k.csv')
df3
# Out:
#      Unnamed: 0 web-scraper-order  \
# 0             0   1553043067-5148
# 1             1   1553043063-5147
# 2             2   1553043059-5146
# 3             3   1553043055-5145
# 4             4   1553043051-5144
# ..          ...               ...
# 995         995   1553037784-3900
# 996         996   1553037792-3901
# 997         997   1553037768-3897
# 998         998   1553037724-3888
# 999         999   1553037758-3896
#
#                                  web-scraper-start-url          userID  \
# 0    https://socialblade.com/youtube/top/5000/mosts...       PewDiePie
# 1    https://socialblade.com/youtube/top/5000/mosts...        T-Series
# 2    https://socialblade.com/youtube/top/5000/mosts...          Gaming
# 3    https://socialblade.com/youtube/top/5000/mosts...  YouTube Movies
# 4    https://socialblade.com/youtube/top/5000/mosts...          Sports
# ..                                                 ...             ...
# ...

# %%
# Out:
#   File "C:\Users\rosey\AppData\Local\Temp/ipykernel_2320/3381529324.py", line 2
#     𝐰𝐡𝐢𝐥𝐞 𝐱 < 10:
#           ^
# SyntaxError: invalid syntax
